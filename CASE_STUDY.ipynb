# %% [markdown]
# (b)

# %%
from pulp import *
#'i' represents places 1--Silicon valley , 2-Big cities , 3--Small towns.
#'j' represents age groups 1-->18-25 , 2-->26-40 , 3-->41-50, 4-->51+ age.
"""Xij represents number of customers interviewed belonging to i place and j age group"""
""" """
prob=LpProblem(name="Stock",sense=LpMinimize)
x11=LpVariable("x11",lowBound=0,cat=LpInteger)
x12=LpVariable("x12",lowBound=0,cat=LpInteger)
x13=LpVariable("x13",lowBound=0,cat=LpInteger)
x14=LpVariable("x14",lowBound=0,cat=LpInteger)
x21=LpVariable("x21",lowBound=0,cat=LpInteger)
x22=LpVariable("x22",lowBound=0,cat=LpInteger)
x23=LpVariable("x23",lowBound=0,cat=LpInteger)
x24=LpVariable("x24",lowBound=0,cat=LpInteger)
x31=LpVariable("x31",lowBound=0,cat=LpInteger)
x32=LpVariable("x32",lowBound=0,cat=LpInteger)
x33=LpVariable("x33",lowBound=0,cat=LpInteger)
x34=LpVariable("x34",lowBound=0,cat=LpInteger)

prob+= 4.75*x11 + 6.5*x12 + 6.5*x13 + 5*x14 + 5.25*x21 + 5.75*x22 + 6.25*x23 + 6.25*x24 + 6.5*x31 + 7.5*x32 + 7.5*x33 + 7.25*x34 
prob+= x11 + x21 + x31 >= 400
prob+= x12 + x22 + x32 >= 550
prob+= x13 + x23 + x33 >= 300
prob+= x14 + x24 + x34 >= 300
prob+= x11 + x12 + x13 + x14 >= 300
prob+= x21 + x22 + x23 + x24 >= 700
prob+= x31 + x32 + x33 + x34 >= 400


status=prob.solve()
LpStatus[status]

for i in prob.variables():
    print(i ,' = ' ,value(i))

print("cost of surveying = "value(prob.objective))

print('bidding value = ',1.15*value(prob.objective))
# Out:
# x11  =  150.0
# x12  =  0.0
# x13  =  0.0
# x14  =  300.0
# x21  =  0.0
# x22  =  550.0
# x23  =  150.0
# x24  =  0.0
# x31  =  250.0
# x32  =  0.0
# x33  =  150.0
# x34  =  0.0
# 9062.5
# value_bid= 10421.875

# %% [markdown]
# (c)

# %%
prob=LpProblem(name="Stock",sense=LpMinimize)
x11=LpVariable("x11",lowBound=0,cat=LpInteger)
x12=LpVariable("x12",lowBound=0,cat=LpInteger)
x13=LpVariable("x13",lowBound=0,cat=LpInteger)
x14=LpVariable("x14",lowBound=0,cat=LpInteger)
x21=LpVariable("x21",lowBound=0,cat=LpInteger)
x22=LpVariable("x22",lowBound=0,cat=LpInteger)
x23=LpVariable("x23",lowBound=0,cat=LpInteger)
x24=LpVariable("x24",lowBound=0,cat=LpInteger)
x31=LpVariable("x31",lowBound=0,cat=LpInteger)
x32=LpVariable("x32",lowBound=0,cat=LpInteger)
x33=LpVariable("x33",lowBound=0,cat=LpInteger)
x34=LpVariable("x34",lowBound=0,cat=LpInteger)

prob+= 4.75*x11 + 6.5*x12 + 6.5*x13 + 5*x14 + 5.25*x21 + 5.75*x22 + 6.25*x23 + 6.25*x24 + 6.5*x31 + 7.5*x32 + 7.5*x33 + 7.25*x34 
prob+= x11 + x21 + x31 >= 400
prob+= x12 + x22 + x32 >= 550
prob+= x13 + x23 + x33 >= 300
prob+= x14 + x24 + x34 >= 300
prob+= x11 + x12 + x13 + x14 >= 300
prob+= x21 + x22 + x23 + x24 >= 700
prob+= x31 + x32 + x33 + x34 >= 400
prob+= x11 >= 50
prob+= x12 >= 50
prob+= x13 >= 50
prob+= x14 >= 50
prob+= x21 >= 50
prob+= x22 >= 50
prob+= x23 >= 50
prob+= x24 >= 50
prob+= x31 >= 50
prob+= x32 >= 50
prob+= x33 >= 50
prob+= x34 >= 50

status=prob.solve()
LpStatus[status]

for i in prob.variables():
    print(i ,' = ' ,value(i))
print("cost of surveying = "value(prob.objective))

print('bidding value = ',1.15*value(prob.objective))
# Out:
# x11  =  150.0
# x12  =  50.0
# x13  =  50.0
# x14  =  200.0
# x21  =  50.0
# x22  =  450.0
# x23  =  150.0
# x24  =  50.0
# x31  =  200.0
# x32  =  50.0
# x33  =  100.0
# x34  =  50.0
# 9250.0
# value_bid= 10637.5

# %% [markdown]
# (d)

# %%
prob=LpProblem(name="Stock",sense=LpMinimize)
x11=LpVariable("x11",lowBound=0,cat=LpInteger)
x12=LpVariable("x12",lowBound=0,cat=LpInteger)
x13=LpVariable("x13",lowBound=0,cat=LpInteger)
x14=LpVariable("x14",lowBound=0,cat=LpInteger)
x21=LpVariable("x21",lowBound=0,cat=LpInteger)
x22=LpVariable("x22",lowBound=0,cat=LpInteger)
x23=LpVariable("x23",lowBound=0,cat=LpInteger)
x24=LpVariable("x24",lowBound=0,cat=LpInteger)
x31=LpVariable("x31",lowBound=0,cat=LpInteger)
x32=LpVariable("x32",lowBound=0,cat=LpInteger)
x33=LpVariable("x33",lowBound=0,cat=LpInteger)
x34=LpVariable("x34",lowBound=0,cat=LpInteger)

prob+= 4.75*x11 + 6.5*x12 + 6.5*x13 + 5*x14 + 5.25*x21 + 5.75*x22 + 6.25*x23 + 6.25*x24 + 6.5*x31 + 7.5*x32 + 7.5*x33 + 7.25*x34 
prob+= x11 + x21 + x31 >= 400
prob+= x12 + x22 + x32 >= 550
prob+= x13 + x23 + x33 >= 300
prob+= x14 + x24 + x34 >= 300
prob+= x11 + x12 + x13 + x14 >= 300
prob+= x21 + x22 + x23 + x24 >= 700
prob+= x31 + x32 + x33 + x34 >= 400
prob+= x11 >= 50
prob+= x12 >= 50
prob+= x13 >= 50
prob+= x14 >= 50
prob+= x21 >= 50
prob+= x22 >= 50
prob+= x23 >= 50
prob+= x24 >= 50
prob+= x31 >= 50
prob+= x32 >= 50
prob+= x33 >= 50
prob+= x34 >= 50
prob+= x11 + x21 + x31 >= 600
prob+= x11 + x12 + x13 + x14 >= 650


status=prob.solve()
LpStatus[status]

for i in prob.variables():
    print(i ,' = ' ,value(i))

print("cost of surveying = "value(prob.objective))

print('bidding value = ',1.15*value(prob.objective))
# Out:
# x11  =  350.0
# x12  =  50.0
# x13  =  50.0
# x14  =  200.0
# x21  =  50.0
# x22  =  450.0
# x23  =  150.0
# x24  =  50.0
# x31  =  200.0
# x32  =  50.0
# x33  =  100.0
# x34  =  50.0
# 10200.0
# value_bid= 11730.0

# %% [markdown]
# (e)

# %%
prob=LpProblem(name="Stock",sense=LpMinimize)
x11=LpVariable("x11",lowBound=0,cat=LpInteger)
x12=LpVariable("x12",lowBound=0,cat=LpInteger)
x13=LpVariable("x13",lowBound=0,cat=LpInteger)
x14=LpVariable("x14",lowBound=0,cat=LpInteger)
x21=LpVariable("x21",lowBound=0,cat=LpInteger)
x22=LpVariable("x22",lowBound=0,cat=LpInteger)
x23=LpVariable("x23",lowBound=0,cat=LpInteger)
x24=LpVariable("x24",lowBound=0,cat=LpInteger)
x31=LpVariable("x31",lowBound=0,cat=LpInteger)
x32=LpVariable("x32",lowBound=0,cat=LpInteger)
x33=LpVariable("x33",lowBound=0,cat=LpInteger)
x34=LpVariable("x34",lowBound=0,cat=LpInteger)

prob+= 6.50*x11 + 6.5*x12 + 6.5*x13 + 5*x14 + 6.75*x21 + 5.75*x22 + 6.25*x23 + 6.25*x24 + 7.00*x31 + 7.5*x32 + 7.5*x33 + 7.25*x34 
prob+= x11 + x21 + x31 >= 400
prob+= x12 + x22 + x32 >= 550
prob+= x13 + x23 + x33 >= 300
prob+= x14 + x24 + x34 >= 300
prob+= x11 + x12 + x13 + x14 >= 300
prob+= x21 + x22 + x23 + x24 >= 700
prob+= x31 + x32 + x33 + x34 >= 400
prob+= x11 >= 50
prob+= x12 >= 50
prob+= x13 >= 50
prob+= x14 >= 50
prob+= x21 >= 50
prob+= x22 >= 50
prob+= x23 >= 50
prob+= x24 >= 50
prob+= x31 >= 50
prob+= x32 >= 50
prob+= x33 >= 50
prob+= x34 >= 50
prob+= x11 + x21 + x31 >= 600
prob+= x11 + x12 + x13 + x14 >= 650


status=prob.solve()
LpStatus[status]

for i in prob.variables():
    print(i ,' = ' ,value(i))

print("cost of surveying = "value(prob.objective))

print('bidding value = ',1.15*value(prob.objective))
# Out:
# x11  =  300.0
# x12  =  50.0
# x13  =  100.0
# x14  =  200.0
# x21  =  50.0
# x22  =  450.0
# x23  =  150.0
# x24  =  50.0
# x31  =  250.0
# x32  =  50.0
# x33  =  50.0
# x34  =  50.0
# 10962.5
# value_bid= 12606.874999999998

# %% [markdown]
# (f)

# %%
prob=LpProblem(name="Stock",sense=LpMinimize)
x11=LpVariable("x11",lowBound=0,cat=LpInteger)
x12=LpVariable("x12",lowBound=0,cat=LpInteger)
x13=LpVariable("x13",lowBound=0,cat=LpInteger)
x14=LpVariable("x14",lowBound=0,cat=LpInteger)
x21=LpVariable("x21",lowBound=0,cat=LpInteger)
x22=LpVariable("x22",lowBound=0,cat=LpInteger)
x23=LpVariable("x23",lowBound=0,cat=LpInteger)
x24=LpVariable("x24",lowBound=0,cat=LpInteger)
x31=LpVariable("x31",lowBound=0,cat=LpInteger)
x32=LpVariable("x32",lowBound=0,cat=LpInteger)
x33=LpVariable("x33",lowBound=0,cat=LpInteger)
x34=LpVariable("x34",lowBound=0,cat=LpInteger)

prob+= 6.50*x11 + 6.5*x12 + 6.5*x13 + 5*x14 + 6.75*x21 + 5.75*x22 + 6.25*x23 + 6.25*x24 + 7.00*x31 + 7.5*x32 + 7.5*x33 + 7.25*x34 
prob+= x11 + x21 + x31 >= 500
prob+= x12 + x22 + x32 >= 700
prob+= x13 + x23 + x33 >= 400
prob+= x14 + x24 + x34 >= 400
prob+= x11 + x12 + x13 + x14 >= 400
prob+= x21 + x22 + x23 + x24 >= 1000
prob+= x31 + x32 + x33 + x34 >= 300
prob+= x11 + x21 + x31 <= 500
prob+= x12 + x22 + x32 <= 700
prob+= x13 + x23 + x33 <= 400
prob+= x14 + x24 + x34 <= 400
prob+= x11 + x12 + x13 + x14 <= 400
prob+= x21 + x22 + x23 + x24 <= 1000
prob+= x31 + x32 + x33 + x34 <= 300
prob+= x11 >= 50
prob+= x12 >= 50
prob+= x13 >= 50
prob+= x14 >= 50
prob+= x21 >= 50
prob+= x22 >= 50
prob+= x23 >= 50
prob+= x24 >= 50
prob+= x31 >= 50
prob+= x32 >= 50
prob+= x33 >= 50
prob+= x34 >= 50
prob+= x11 + x21 + x31 >= 600
prob+= x11 + x12 + x13 + x14 >= 650


status=prob.solve()
LpStatus[status]

for i in prob.variables():
    print(i ,' = ' ,value(i))

print("cost of surveying = "value(prob.objective))
print('increase in cost = ',value(prob.objective)-10962.5)
print('bidding value = ',1.15*value(prob.objective))
# Out:
# x11  =  50.0
# x12  =  50.0
# x13  =  50.0
# x14  =  250.0
# x21  =  50.0
# x22  =  600.0
# x23  =  300.0
# x24  =  50.0
# x31  =  500.0
# x32  =  50.0
# x33  =  50.0
# x34  =  100.0
# 13175.0
# value_bid= 15151.249999999998
